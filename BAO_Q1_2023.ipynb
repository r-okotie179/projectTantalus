# %% [markdown]
# <a href="https://colab.research.google.com/github/r-okotie179/projectTantalus/blob/main/BAO_Q1_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Part A**

# %%
import math
def T(f_max, edc=1, ind=0):
    iter = edc * f_max
    T_null = [2,2] # the long, brute force list
    for i in range(iter):
        j = len(T_null)
        next_T = math.ceil(4 * math.log((j + 1), 10)) + T_null[j-1] + math.ceil(((7/20000)*(T_null[j-2])))
        T_null.append(next_T)

    T = []
    if edc != 1:
        for i in range(len(T_null)):
            k = i + 1
            if k%edc == 0:
                T.append(T_null[i])
    if len(T) == 0:
        return T_null
    else:
        return T

a = T(498, 23)
print(a[(33-1)])
print(a[498-1])
# Out:
# 9333
# 2122215

# %% [markdown]
# **Part D**

# %%
def T(f_max=60, edc=23, ind=0):
    iter = edc * f_max
    T_null = [2,2] # the long, brute force list
    for i in range(iter):
        j = len(T_null)
        next_T = math.ceil(4 * math.log((j + 1), 10)) + T_null[j-1] + math.ceil(((7/20000)*(T_null[j-2])))
        T_null.append(next_T)

    T = []
    if edc != 1:
        for i in range(len(T_null)):
            k = i + 1
            if k%edc == 0:
                T.append(T_null[i])
    return T # returns list

def W(f):
    # number of wires on the fth floor
    W = int(f**2 + f * ((2**f) - 1.5) * (f+1))
    return W

def R(f):
    S = (2 ** (f+1)) - 3
    R = T()[f-1] + W(f)
    # truncate R to be the first 4 digits since it grows largely
    R = str(R).strip()[:4]
    print(S, R)

R(52)
# Out:
# 9007199254740989 1241

# %% [markdown]
# This is wrong and I do not understand where the error could even be so I will move onto the later questions and return to this code in a bit.
