# %% [markdown]
# <a href="https://colab.research.google.com/github/r-okotie179/projectTantalus/blob/main/BAO_Q2_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math

lst = np.arange(1, 33, 1)
def inefficient_pair(n): # first run of the list process, now using the modulus sign
    pos = n-1
    b = lst[pos]
    u = pos + 16
    if u > 32:
        u = pos - 16
    elif n == 17:
        u = 0
    c = lst[u]
    print(b, c)

def pair(n):
    pos = n-1
    a = lst[pos]
    b = lst[(pos+16)%(len(lst))]
    print(a, b)

# %%
def PET(time, position):
    '''
    finding angle
    '''
    # input time is in nanoseconds
    time = (time)
    ind = time.index(min(time))
    closest_pos = position[ind]
    dictionary = {"A":0.25, "B":0.5, "C":0.75} # dictionaries are a more efficient way than a bunch of if/else statements
    conv_pos = (closest_pos[0] - 1) + dictionary.get(closest_pos[1])
    if conv_pos < 0:
        conv_pos = dictionary.get(closest_pos[1])
    angle = (conv_pos / 32) * 360
    angle = format(angle, ",.2f")

    '''
    finding distance
    '''
    min_time = min(time) * (10**-9)
    c = 3*(10**8)
    l = c * min_time
    d = (0.45 - l) * 100 # centimetres
    d = format(d, ",.2f")
    print(angle, d)

time = [1.000, 2.000]
position = [[20, "B"], [4, "B"]]

PET(time, position)
# Out:
# 219.38 15.00
