# %% [markdown]
# <a href="https://colab.research.google.com/github/r-okotie179/projectTantalus/blob/main/charity/folium_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using folium will be how I do the initial data analysis on the distribution of charity places.

# %%
pip install folium

# %%
import pandas as pd
import folium
import requests
import io

# %%
url = "https://raw.githubusercontent.com/r-okotie179/projectTantalus/charity/MPS_Ward_Level_Crime.csv"

# personal token
headers = {
    "Authorization":"token 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"
}

response = requests.get(url, headers=headers)

# read text response into pandas
if response.status_code == 200:
    df = pd.read_csv(io.StringIO(response.text))
    print("")
else:
    print("Failed to fetch")
# Out:
# Failed to fetch
