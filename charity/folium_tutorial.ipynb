# %% [markdown]
# <a href="https://colab.research.google.com/github/r-okotie179/projectTantalus/blob/main/folium_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using folium will be how I do the initial data analysis on the distribution of charity places.

# %%
pip install folium

# %%
import pandas as pd
import folium

# %%
input_data = r"C:\Users\25okotir\OneDrive - Bishops Stortford College\Data\MPS Ward Level Crime (most recent 24 months).csv"
df = pd.read_csv(input_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_624/3407940522.py in <cell line: 0>()
#       1 input_data = r"C:\Users\25okotir\OneDrive - Bishops Stortford College\Data\MPS Ward Level Crime (most recent 24 months).csv"
# ----> 2 df = pd.read_csv(input_data)
#
# ...
