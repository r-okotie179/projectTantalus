# %% [markdown]
# <a href="https://colab.research.google.com/github/r-okotie179/projectTantalus/blob/main/charity/folium_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using folium will be how I do the initial data analysis on the distribution of charity places.

# %%
pip install folium

# %%
import pandas as pd
import folium
import requests
import io

# %%
# to access secret key for the private repo
from google.colab import userdata
token = userdata.get('GITHUB_PA')

# %%
url_001 = "https://raw.githubusercontent.com/r-okotie179/projectTantalus/main/charity/MPS Ward Level Crime (most recent 24 months).csv"
url_002 = "https://raw.githubusercontent.com/r-okotie179/projectTantalus/main/charity/london_boroughs.csv"
# personal token
headers = {
    "Authorization":f"token {token}"
}

response_001 = requests.get(url_001, headers=headers)
response_002 = requests.get(url_002, headers=headers)
# read text response into pandas
if response_001.status_code == 200 and response_002.status_code == 200:
    df_001 = pd.read_csv(io.StringIO(response_001.text))
    df_002 = pd.read_csv(io.StringIO(response_002.text))
else:
    print("Failed to fetch")

# %%
# for the london boroughs, find the first instance of a borough name being mentioned and use those latitude and longtiude data (maybe later find the average)

# then pair that data with what is extracted from the crime data (this is quite meaningless)

# %%
'''
Focusing on the tutorial, I will just test folium with Bishop's Stortford lat/long
'''

# 51.869° N, 0.158° E
m = folium.Map(location=(51.889,0.1))
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
